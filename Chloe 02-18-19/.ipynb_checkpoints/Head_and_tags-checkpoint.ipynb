# %%
from hdx.utilities.easy_logging import setup_logging
from hdx.hdx_configuration import Configuration
from hdx.data.dataset import Dataset
import os
import numpy as np
import pandas as pd

# %%
setup_logging()
Configuration.create(hdx_site='prod', user_agent='A_Quick_Example', hdx_read_only=True)

# %%
#Check if the dataset has at least 1 resource of the required file type(s).

def check_type(dataset, file_types=[]):
    temp_dataset = Dataset.read_from_hdx(dataset)
    temp_dataset.separate_resources()
    if (len(temp_dataset.resources) > 0):
        if (len(file_types) > 0):
            if (not set(temp_dataset.get_filetypes()).isdisjoint(file_types)): 
                    return True
        else :
            return True
    return False

# %%
# Check if the dataset is tagged with HXL tag, not provided by HXL

def check_organization(dataset):
    if dataset.get_organization()['title'] != 'Humanitarian Exchange Language(HXL)':
            return True
    return False

# %%
# Download one dataset with certain type(s), read it into Dataframe, 
# add all headers, tags and dataset names to our DataFrame,
# and delete the dataset

def process_dataset(dataset, file_type, dataframe, download_path, index):
    global count
# Download one dataset and read it into a DataFrame 
    if (file_type == None):
        url, path = dataset_1.resources[0].download(download_path)
        pandas_dataset = pd.read_csv(path)
    else:
        if (file_type not in dataset.get_filetypes()):
            return 'Error: Required file type not in dataset OR dataset does not contain any resources.'
        try:
            url, path = dataset.resources[dataset.get_filetypes().index(file_type)].download(download_path)
            print('Resource URL %s downloaded to %s' % (url, path))
            pandas_dataset = pd.read_csv(path, encoding='latin-1')
        except:
            return 'Unknown error.'
     
    if "HXL" in os.path.basename(path) or "hxl" in os.path.basename(path):
        return
    dataset_df = pandas_dataset.head()
    
# Add headers and tags to our DataFrame
    if len(dataset_df) > 2:
        headers = list(dataset_df.columns.values)
        tags = list(dataset_df.iloc[0,:])
        for i in range(len(headers)):
            try:
                dic = {'Header': headers[i], 'Tag': tags[i], 'Dataset_name': os.path.basename(path), 'Index': index}
                headers_and_tags.loc[len(headers_and_tags)] = dic
            except:
                print("Error: different number of headers and tags")
        count += 1
    os.remove(path)
    print("File Removed!")
    return

# %%
# Search for all datasets with HXL tags

datasets_HXL = Dataset.search_in_hdx('HXL')
len(datasets_HXL)
# Out:
# 3399

# %%
# Create a DataFrame for all headers and tags

col_names = ['Header', 'Tag', 'Dataset_name', 'Index']
headers_and_tags= pd.DataFrame(columns = col_names)

# %%
count = 0
for i in range(1000):
    process_dataset(datasets_HXL[i], 'CSV', headers_and_tags, './datasets', count)
# Out:
# Resource URL https://docs.google.com/spreadsheets/d/1En9FlmM8PrbTWgl3UHPF_MXnJ6ziVZFhBbojSJzBdLI/pub?gid=319251406&single=true&output=csv downloaded to ./datasets/hxl-core-hashtag-schema.csv3.CSV
# Resource URL https://docs.google.com/spreadsheets/d/e/2PACX-1vRiQVi4J8HMWACq6JJpKT1EfKcwYh3xhYmNrgz9Qo9NBngoQxFRKxDPkhu09RrWj81D0fsKJ4PDoYdI/pub?output=csv downloaded to ./datasets/HXL master vocabulary list3.CSV
# Resource URL https://docs.google.com/spreadsheets/d/1c9wehuauQAAegElIRI6vhWktKSI-PcPjHHiXdqASonk/export?format=csv&gid=1170456449 downloaded to ./datasets/Functional Roles (Beta) - CSV.CSV
# File Removed!
# Resource URL https://ftsarchive.unocha.org/docs/IATICodelist_HS2-1.csv downloaded to ./datasets/IATICodelist_HS2-1.csv.CSV
# File Removed!
# Resource URL http://data.humdata.org/dataset/a7c3de5e-ff27-4746-99cd-05f2ad9b1066/resource/d9fc551a-b5e4-4bed-9d0d-b047b6961817/download/nga_pop_adm1_2016.csv downloaded to ./datasets/Nga_pop_adm1_2016.csv.CSV
# File Removed!
# Resource URL https://docs.google.com/spreadsheets/d/1paoIpHiYo7dy_dnf_luUSfowWDwNAWwS3z4GHL2J7Rc/export?format=csv&id=1paoIpHiYo7dy_dnf_luUSfowWDwNAWwS3z4GHL2J7Rc&gid=2077872077 downloaded to ./datasets/Guinea Health Facilities.CSV
# File Removed!
# Resource URL http://ourairports.com/countries/UA/airports.hxl downloaded to ./datasets/List of airports in Ukraine (HXL tags).CSV
# Resource URL http://ourairports.com/countries/US/airports.hxl downloaded to ./datasets/List of airports in United States of America (HXL tags).CSV
# Resource URL http://ourairports.com/countries/TH/airports.hxl downloaded to ./datasets/List of airports in Thailand (HXL tags).CSV
# Resource URL http://ourairports.com/countries/ZW/airports.hxl downloaded to ./datasets/List of airports in Zimbabwe (HXL tags).CSV
# Resource URL http://ourairports.com/countries/ZA/airports.hxl downloaded to ./datasets/List of airports in South Africa (HXL tags).CSV
# Resource URL http://ourairports.com/countries/ID/airports.hxl downloaded to ./datasets/List of airports in Indonesia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/HU/airports.hxl downloaded to ./datasets/List of airports in Hungary (HXL tags).CSV
# Resource URL http://ourairports.com/countries/GT/airports.hxl downloaded to ./datasets/List of airports in Guatemala (HXL tags).CSV
# Resource URL http://ourairports.com/countries/CV/airports.hxl downloaded to ./datasets/List of airports in Cabo Verde (HXL tags).CSV
# Resource URL http://ourairports.com/countries/CL/airports.hxl downloaded to ./datasets/List of airports in Chile (HXL tags).CSV
# Resource URL http://ourairports.com/countries/IT/airports.hxl downloaded to ./datasets/List of airports in Italy (HXL tags).CSV
# Resource URL http://ourairports.com/countries/BD/airports.hxl downloaded to ./datasets/List of airports in Bangladesh (HXL tags).CSV
# Resource URL http://ourairports.com/countries/FJ/airports.hxl downloaded to ./datasets/List of airports in Fiji (HXL tags).CSV
# Resource URL http://ourairports.com/countries/CZ/airports.hxl downloaded to ./datasets/List of airports in Czech Republic (HXL tags).CSV
# Resource URL http://ourairports.com/countries/BF/airports.hxl downloaded to ./datasets/List of airports in Burkina Faso (HXL tags).CSV
# Resource URL http://ourairports.com/countries/FR/airports.hxl downloaded to ./datasets/List of airports in France (HXL tags).CSV
# Resource URL http://ourairports.com/countries/EC/airports.hxl downloaded to ./datasets/List of airports in Ecuador (HXL tags).CSV
# Resource URL http://ourairports.com/countries/CA/airports.hxl downloaded to ./datasets/List of airports in Canada (HXL tags).CSV
# Resource URL http://ourairports.com/countries/AT/airports.hxl downloaded to ./datasets/List of airports in Austria (HXL tags).CSV
# Resource URL http://ourairports.com/countries/CN/airports.hxl downloaded to ./datasets/List of airports in China (HXL tags).CSV
# Resource URL http://ourairports.com/countries/BG/airports.hxl downloaded to ./datasets/List of airports in Bulgaria (HXL tags).CSV
# Resource URL http://ourairports.com/countries/AR/airports.hxl downloaded to ./datasets/List of airports in Argentina (HXL tags).CSV
# Resource URL http://ourairports.com/countries/IN/airports.hxl downloaded to ./datasets/List of airports in India (HXL tags).CSV
# Resource URL http://ourairports.com/countries/BR/airports.hxl downloaded to ./datasets/List of airports in Brazil (HXL tags).CSV
# Resource URL http://ourairports.com/countries/IL/airports.hxl downloaded to ./datasets/List of airports in Israel (HXL tags).CSV
# Resource URL http://ourairports.com/countries/ES/airports.hxl downloaded to ./datasets/List of airports in Spain (HXL tags).CSV
# Resource URL http://ourairports.com/countries/DK/airports.hxl downloaded to ./datasets/List of airports in Denmark (HXL tags).CSV
# Resource URL http://ourairports.com/countries/BE/airports.hxl downloaded to ./datasets/List of airports in Belgium (HXL tags).CSV
# Resource URL http://ourairports.com/countries/AU/airports.hxl downloaded to ./datasets/List of airports in Australia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/LR/airports.hxl downloaded to ./datasets/List of airports in Liberia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/CO/airports.hxl downloaded to ./datasets/List of airports in Colombia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/IE/airports.hxl downloaded to ./datasets/List of airports in Ireland (HXL tags).CSV
# Resource URL http://ourairports.com/countries/AL/airports.hxl downloaded to ./datasets/List of airports in Albania (HXL tags).CSV
# Resource URL http://ourairports.com/countries/DE/airports.hxl downloaded to ./datasets/List of airports in Germany (HXL tags).CSV
# Resource URL http://ourairports.com/countries/BW/airports.hxl downloaded to ./datasets/List of airports in Botswana (HXL tags).CSV
# Resource URL http://ourairports.com/countries/AF/airports.hxl downloaded to ./datasets/List of airports in Afghanistan (HXL tags).CSV
# Resource URL http://ourairports.com/countries/AO/airports.hxl downloaded to ./datasets/List of airports in Angola (HXL tags).CSV
# Resource URL http://ourairports.com/countries/LV/airports.hxl downloaded to ./datasets/List of airports in Latvia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/MD/airports.hxl downloaded to ./datasets/List of airports in Republic of Moldova (HXL tags).CSV
# Resource URL http://ourairports.com/countries/MG/airports.hxl downloaded to ./datasets/List of airports in Madagascar (HXL tags).CSV
# Resource URL http://ourairports.com/countries/PL/airports.hxl downloaded to ./datasets/List of airports in Poland (HXL tags).CSV
# Resource URL http://ourairports.com/countries/PF/airports.hxl downloaded to ./datasets/List of airports in French Polynesia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/SN/airports.hxl downloaded to ./datasets/List of airports in Senegal (HXL tags).CSV
# Resource URL http://ourairports.com/countries/PG/airports.hxl downloaded to ./datasets/List of airports in Papua New Guinea (HXL tags).CSV
# Resource URL http://ourairports.com/countries/NL/airports.hxl downloaded to ./datasets/List of airports in Netherlands (HXL tags).CSV
# Resource URL http://ourairports.com/countries/PH/airports.hxl downloaded to ./datasets/List of airports in Philippines (HXL tags).CSV
# Resource URL http://ourairports.com/countries/RW/airports.hxl downloaded to ./datasets/List of airports in Rwanda (HXL tags).CSV
# Resource URL http://ourairports.com/countries/RO/airports.hxl downloaded to ./datasets/List of airports in Romania (HXL tags).CSV
# Resource URL http://ourairports.com/countries/PT/airports.hxl downloaded to ./datasets/List of airports in Portugal (HXL tags).CSV
# Resource URL http://ourairports.com/countries/NA/airports.hxl downloaded to ./datasets/List of airports in Namibia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/RU/airports.hxl downloaded to ./datasets/List of airports in Russian Federation (HXL tags).CSV
# Resource URL http://ourairports.com/countries/NG/airports.hxl downloaded to ./datasets/List of airports in Nigeria (HXL tags).CSV
# Resource URL http://ourairports.com/countries/MZ/airports.hxl downloaded to ./datasets/List of airports in Mozambique (HXL tags).CSV
# Resource URL http://ourairports.com/countries/NO/airports.hxl downloaded to ./datasets/List of airports in Norway (HXL tags).CSV
# Resource URL http://ourairports.com/countries/ML/airports.hxl downloaded to ./datasets/List of airports in Mali (HXL tags).CSV
# Resource URL http://ourairports.com/countries/MN/airports.hxl downloaded to ./datasets/List of airports in Mongolia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/SL/airports.hxl downloaded to ./datasets/List of airports in Sierra Leone (HXL tags).CSV
# Resource URL http://ourairports.com/countries/MU/airports.hxl downloaded to ./datasets/List of airports in Mauritius (HXL tags).CSV
# Resource URL http://ourairports.com/countries/MY/airports.hxl downloaded to ./datasets/List of airports in Malaysia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/NP/airports.hxl downloaded to ./datasets/List of airports in Nepal (HXL tags).CSV
# Resource URL http://ourairports.com/countries/NE/airports.hxl downloaded to ./datasets/List of airports in Niger (HXL tags).CSV
# Resource URL http://ourairports.com/countries/SI/airports.hxl downloaded to ./datasets/List of airports in Slovenia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/SE/airports.hxl downloaded to ./datasets/List of airports in Sweden (HXL tags).CSV
# Resource URL http://ourairports.com/countries/SC/airports.hxl downloaded to ./datasets/List of airports in Seychelles (HXL tags).CSV
# Resource URL http://ourairports.com/countries/SK/airports.hxl downloaded to ./datasets/List of airports in Slovakia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/TD/airports.hxl downloaded to ./datasets/List of airports in Chad (HXL tags).CSV
# Resource URL http://ourairports.com/countries/UG/airports.hxl downloaded to ./datasets/List of airports in Uganda (HXL tags).CSV
# Resource URL http://ourairports.com/countries/TN/airports.hxl downloaded to ./datasets/List of airports in Tunisia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/TM/airports.hxl downloaded to ./datasets/List of airports in Turkmenistan (HXL tags).CSV
# Resource URL http://ourairports.com/countries/TR/airports.hxl downloaded to ./datasets/List of airports in Turkey (HXL tags).CSV
# Resource URL http://ourairports.com/countries/BY/airports.hxl downloaded to ./datasets/List of airports in Belarus (HXL tags).CSV
# Resource URL http://ourairports.com/countries/CH/airports.hxl downloaded to ./datasets/List of airports in Switzerland (HXL tags).CSV
# Resource URL http://ourairports.com/countries/KE/airports.hxl downloaded to ./datasets/List of airports in Kenya (HXL tags).CSV
# Resource URL http://ourairports.com/countries/HR/airports.hxl downloaded to ./datasets/List of airports in Croatia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/BZ/airports.hxl downloaded to ./datasets/List of airports in Belize (HXL tags).CSV
# Resource URL http://ourairports.com/countries/MA/airports.hxl downloaded to ./datasets/List of airports in Morocco (HXL tags).CSV
# Resource URL http://ourairports.com/countries/MX/airports.hxl downloaded to ./datasets/List of airports in Mexico (HXL tags).CSV
# Resource URL http://ourairports.com/countries/PE/airports.hxl downloaded to ./datasets/List of airports in Peru (HXL tags).CSV
# Resource URL http://ourairports.com/countries/SO/airports.hxl downloaded to ./datasets/List of airports in Somalia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/GR/airports.hxl downloaded to ./datasets/List of airports in Greece (HXL tags).CSV
# Resource URL http://ourairports.com/countries/BS/airports.hxl downloaded to ./datasets/List of airports in Bahamas (HXL tags).CSV
# Resource URL http://ourairports.com/countries/AE/airports.hxl downloaded to ./datasets/List of airports in United Arab Emirates (HXL tags).CSV
# Resource URL http://ourairports.com/countries/JP/airports.hxl downloaded to ./datasets/List of airports in Japan (HXL tags).CSV
# Resource URL http://ourairports.com/countries/LU/airports.hxl downloaded to ./datasets/List of airports in Luxembourg (HXL tags).CSV
# Resource URL http://ourairports.com/countries/RS/airports.hxl downloaded to ./datasets/List of airports in Serbia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/KR/airports.hxl downloaded to ./datasets/List of airports in Republic of Korea (HXL tags).CSV
# Resource URL http://ourairports.com/countries/SD/airports.hxl downloaded to ./datasets/List of airports in Sudan (HXL tags).CSV
# Resource URL http://ourairports.com/countries/GY/airports.hxl downloaded to ./datasets/List of airports in Guyana (HXL tags).CSV
# Resource URL http://ourairports.com/countries/CU/airports.hxl downloaded to ./datasets/List of airports in Cuba (HXL tags).CSV
# Resource URL http://ourairports.com/countries/EE/airports.hxl downloaded to ./datasets/List of airports in Estonia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/AG/airports.hxl downloaded to ./datasets/List of airports in Antigua and Barbuda (HXL tags).CSV
# Resource URL http://ourairports.com/countries/FI/airports.hxl downloaded to ./datasets/List of airports in Finland (HXL tags).CSV
# Resource URL http://ourairports.com/countries/LY/airports.hxl downloaded to ./datasets/List of airports in Libya (HXL tags).CSV
# Resource URL http://ourairports.com/countries/IQ/airports.hxl downloaded to ./datasets/List of airports in Iraq (HXL tags).CSV
# Resource URL http://ourairports.com/countries/CR/airports.hxl downloaded to ./datasets/List of airports in Costa Rica (HXL tags).CSV
# Resource URL http://ourairports.com/countries/DM/airports.hxl downloaded to ./datasets/List of airports in Dominica (HXL tags).CSV
# Resource URL http://ourairports.com/countries/LT/airports.hxl downloaded to ./datasets/List of airports in Lithuania (HXL tags).CSV
# Resource URL http://ourairports.com/countries/SA/airports.hxl downloaded to ./datasets/List of airports in Saudi Arabia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/MP/airports.hxl downloaded to ./datasets/List of airports in Northern Mariana Islands (HXL tags).CSV
# Resource URL http://ourairports.com/countries/MM/airports.hxl downloaded to ./datasets/List of airports in Myanmar (HXL tags).CSV
# Resource URL http://ourairports.com/countries/PY/airports.hxl downloaded to ./datasets/List of airports in Paraguay (HXL tags).CSV
# Resource URL http://ourairports.com/countries/PR/airports.hxl downloaded to ./datasets/List of airports in Puerto Rico (HXL tags).CSV
# Resource URL http://ourairports.com/countries/OM/airports.hxl downloaded to ./datasets/List of airports in Oman (HXL tags).CSV
# Resource URL http://ourairports.com/countries/SY/airports.hxl downloaded to ./datasets/List of airports in Syrian Arab Republic (HXL tags).CSV
# Resource URL http://ourairports.com/countries/UZ/airports.hxl downloaded to ./datasets/List of airports in Uzbekistan (HXL tags).CSV
# Resource URL http://ourairports.com/countries/VN/airports.hxl downloaded to ./datasets/List of airports in Viet Nam (HXL tags).CSV
# Resource URL http://ourairports.com/countries/HT/airports.hxl downloaded to ./datasets/List of airports in Haiti (HXL tags).CSV
# Resource URL http://ourairports.com/countries/GQ/airports.hxl downloaded to ./datasets/List of airports in Equatorial Guinea (HXL tags).CSV
# Resource URL http://ourairports.com/countries/HN/airports.hxl downloaded to ./datasets/List of airports in Honduras (HXL tags).CSV
# Resource URL http://ourairports.com/countries/LC/airports.hxl downloaded to ./datasets/List of airports in Saint Lucia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/KY/airports.hxl downloaded to ./datasets/List of airports in Cayman Islands (HXL tags).CSV
# Resource URL http://ourairports.com/countries/GE/airports.hxl downloaded to ./datasets/List of airports in Georgia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/DZ/airports.hxl downloaded to ./datasets/List of airports in Algeria (HXL tags).CSV
# Resource URL http://ourairports.com/countries/GU/airports.hxl downloaded to ./datasets/List of airports in Guam (HXL tags).CSV
# Resource URL http://ourairports.com/countries/EG/airports.hxl downloaded to ./datasets/List of airports in Egypt (HXL tags).CSV
# Resource URL http://ourairports.com/countries/KZ/airports.hxl downloaded to ./datasets/List of airports in Kazakhstan (HXL tags).CSV
# Resource URL http://ourairports.com/countries/GA/airports.hxl downloaded to ./datasets/List of airports in Gabon (HXL tags).CSV
# Resource URL http://ourairports.com/countries/CY/airports.hxl downloaded to ./datasets/List of airports in Cyprus (HXL tags).CSV
# Resource URL http://ourairports.com/countries/AD/airports.hxl downloaded to ./datasets/List of airports in Andorra (HXL tags).CSV
# Resource URL http://ourairports.com/countries/CF/airports.hxl downloaded to ./datasets/List of airports in Central African Republic (HXL tags).CSV
# Resource URL http://ourairports.com/countries/BA/airports.hxl downloaded to ./datasets/List of airports in Bosnia and Herzegovina (HXL tags).CSV
# Resource URL http://ourairports.com/countries/IS/airports.hxl downloaded to ./datasets/List of airports in Iceland (HXL tags).CSV
# Resource URL http://ourairports.com/countries/ET/airports.hxl downloaded to ./datasets/List of airports in Ethiopia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/GL/airports.hxl downloaded to ./datasets/List of airports in Greenland (HXL tags).CSV
# Resource URL http://ourairports.com/countries/CG/airports.hxl downloaded to ./datasets/List of airports in Congo (HXL tags).CSV
# Resource URL http://ourairports.com/countries/MW/airports.hxl downloaded to ./datasets/List of airports in Malawi (HXL tags).CSV
# Resource URL http://ourairports.com/countries/NZ/airports.hxl downloaded to ./datasets/List of airports in New Zealand (HXL tags).CSV
# Resource URL http://ourairports.com/countries/PK/airports.hxl downloaded to ./datasets/List of airports in Pakistan (HXL tags).CSV
# Resource URL http://ourairports.com/countries/ME/airports.hxl downloaded to ./datasets/List of airports in Montenegro (HXL tags).CSV
# Resource URL http://ourairports.com/countries/SG/airports.hxl downloaded to ./datasets/List of airports in Singapore (HXL tags).CSV
# Resource URL http://ourairports.com/countries/PA/airports.hxl downloaded to ./datasets/List of airports in Panama (HXL tags).CSV
# Resource URL http://ourairports.com/countries/SB/airports.hxl downloaded to ./datasets/List of airports in Solomon Islands (HXL tags).CSV
# Resource URL http://ourairports.com/countries/PW/airports.hxl downloaded to ./datasets/List of airports in Palau (HXL tags).CSV
# Resource URL http://ourairports.com/countries/QA/airports.hxl downloaded to ./datasets/List of airports in Qatar (HXL tags).CSV
# Resource URL http://ourairports.com/countries/TV/airports.hxl downloaded to ./datasets/List of airports in Tuvalu (HXL tags).CSV
# Resource URL http://ourairports.com/countries/TT/airports.hxl downloaded to ./datasets/List of airports in Trinidad and Tobago (HXL tags).CSV
# Resource URL http://ourairports.com/countries/UY/airports.hxl downloaded to ./datasets/List of airports in Uruguay (HXL tags).CSV
# Resource URL http://ourairports.com/countries/ZM/airports.hxl downloaded to ./datasets/List of airports in Zambia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/YE/airports.hxl downloaded to ./datasets/List of airports in Yemen (HXL tags).CSV
# Resource URL http://ourairports.com/countries/WS/airports.hxl downloaded to ./datasets/List of airports in Samoa (HXL tags).CSV
# Resource URL http://ourairports.com/countries/WF/airports.hxl downloaded to ./datasets/List of airports in Wallis and Futuna Islands (HXL tags).CSV
# Resource URL http://ourairports.com/countries/VU/airports.hxl downloaded to ./datasets/List of airports in Vanuatu (HXL tags).CSV
# Resource URL http://ourairports.com/countries/VI/airports.hxl downloaded to ./datasets/List of airports in United States Virgin Islands (HXL tags).CSV
# Resource URL http://ourairports.com/countries/VG/airports.hxl downloaded to ./datasets/List of airports in British Virgin Islands (HXL tags).CSV
# Resource URL http://ourairports.com/countries/VE/airports.hxl downloaded to ./datasets/List of airports in Venezuela (Bolivarian Republic of) (HXL tags).CSV
# Resource URL http://ourairports.com/countries/VA/airports.hxl downloaded to ./datasets/List of airports in Holy See (HXL tags).CSV
# Resource URL http://ourairports.com/countries/TO/airports.hxl downloaded to ./datasets/List of airports in Tonga (HXL tags).CSV
# Resource URL http://ourairports.com/countries/TL/airports.hxl downloaded to ./datasets/List of airports in Timor-Leste (HXL tags).CSV
# Resource URL http://ourairports.com/countries/TK/airports.hxl downloaded to ./datasets/List of airports in Tokelau (HXL tags).CSV
# Resource URL http://ourairports.com/countries/TJ/airports.hxl downloaded to ./datasets/List of airports in Tajikistan (HXL tags).CSV
# Resource URL http://ourairports.com/countries/TG/airports.hxl downloaded to ./datasets/List of airports in Togo (HXL tags).CSV
# Resource URL http://ourairports.com/countries/TC/airports.hxl downloaded to ./datasets/List of airports in Turks and Caicos Islands (HXL tags).CSV
# Resource URL http://ourairports.com/countries/SZ/airports.hxl downloaded to ./datasets/List of airports in Swaziland (HXL tags).CSV
# Resource URL http://ourairports.com/countries/SR/airports.hxl downloaded to ./datasets/List of airports in Suriname (HXL tags).CSV
# Resource URL http://ourairports.com/countries/ST/airports.hxl downloaded to ./datasets/List of airports in Sao Tome and Principe (HXL tags).CSV
# Resource URL http://ourairports.com/countries/SS/airports.hxl downloaded to ./datasets/List of airports in South Sudan (HXL tags).CSV
# Resource URL http://ourairports.com/countries/PM/airports.hxl downloaded to ./datasets/List of airports in Saint Pierre and Miquelon (HXL tags).CSV
# Resource URL http://ourairports.com/countries/SM/airports.hxl downloaded to ./datasets/List of airports in San Marino (HXL tags).CSV
# Resource URL http://ourairports.com/countries/SV/airports.hxl downloaded to ./datasets/List of airports in El Salvador (HXL tags).CSV
# Resource URL http://ourairports.com/countries/SH/airports.hxl downloaded to ./datasets/List of airports in Saint Helena (HXL tags).CSV
# Resource URL http://ourairports.com/countries/RE/airports.hxl downloaded to ./datasets/List of airports in Réunion (HXL tags).CSV
# Resource URL http://ourairports.com/countries/PS/airports.hxl downloaded to ./datasets/List of airports in State of Palestine (HXL tags).CSV
# Resource URL http://ourairports.com/countries/PN/airports.hxl downloaded to ./datasets/List of airports in Pitcairn (HXL tags).CSV
# Resource URL http://ourairports.com/countries/NR/airports.hxl downloaded to ./datasets/List of airports in Nauru (HXL tags).CSV
# Resource URL http://ourairports.com/countries/NU/airports.hxl downloaded to ./datasets/List of airports in Niue (HXL tags).CSV
# Resource URL http://ourairports.com/countries/NI/airports.hxl downloaded to ./datasets/List of airports in Nicaragua (HXL tags).CSV
# Resource URL http://ourairports.com/countries/NF/airports.hxl downloaded to ./datasets/List of airports in Norfolk Island (HXL tags).CSV
# Resource URL http://ourairports.com/countries/NC/airports.hxl downloaded to ./datasets/List of airports in New Caledonia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/YT/airports.hxl downloaded to ./datasets/List of airports in Mayotte (HXL tags).CSV
# Resource URL http://ourairports.com/countries/MQ/airports.hxl downloaded to ./datasets/List of airports in Martinique (HXL tags).CSV
# Resource URL http://ourairports.com/countries/MS/airports.hxl downloaded to ./datasets/List of airports in Montserrat (HXL tags).CSV
# Resource URL http://ourairports.com/countries/MR/airports.hxl downloaded to ./datasets/List of airports in Mauritania (HXL tags).CSV
# Resource URL http://ourairports.com/countries/MT/airports.hxl downloaded to ./datasets/List of airports in Malta (HXL tags).CSV
# Resource URL http://ourairports.com/countries/MH/airports.hxl downloaded to ./datasets/List of airports in Marshall Islands (HXL tags).CSV
# Resource URL http://ourairports.com/countries/MV/airports.hxl downloaded to ./datasets/List of airports in Maldives (HXL tags).CSV
# Resource URL http://ourairports.com/countries/MC/airports.hxl downloaded to ./datasets/List of airports in Monaco (HXL tags).CSV
# Resource URL http://ourairports.com/countries/LS/airports.hxl downloaded to ./datasets/List of airports in Lesotho (HXL tags).CSV
# Resource URL http://ourairports.com/countries/LK/airports.hxl downloaded to ./datasets/List of airports in Sri Lanka (HXL tags).CSV
# Resource URL http://ourairports.com/countries/LI/airports.hxl downloaded to ./datasets/List of airports in Liechtenstein (HXL tags).CSV
# Resource URL http://ourairports.com/countries/LB/airports.hxl downloaded to ./datasets/List of airports in Lebanon (HXL tags).CSV
# Resource URL http://ourairports.com/countries/KW/airports.hxl downloaded to ./datasets/List of airports in Kuwait (HXL tags).CSV
# Resource URL http://ourairports.com/countries/KN/airports.hxl downloaded to ./datasets/List of airports in Saint Kitts and Nevis (HXL tags).CSV
# Resource URL http://ourairports.com/countries/KI/airports.hxl downloaded to ./datasets/List of airports in Kiribati (HXL tags).CSV
# Resource URL http://ourairports.com/countries/KH/airports.hxl downloaded to ./datasets/List of airports in Cambodia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/KG/airports.hxl downloaded to ./datasets/List of airports in Kyrgyzstan (HXL tags).CSV
# Resource URL http://ourairports.com/countries/JO/airports.hxl downloaded to ./datasets/List of airports in Jordan (HXL tags).CSV
# Resource URL http://ourairports.com/countries/JM/airports.hxl downloaded to ./datasets/List of airports in Jamaica (HXL tags).CSV
# Resource URL http://ourairports.com/countries/GF/airports.hxl downloaded to ./datasets/List of airports in French Guiana (HXL tags).CSV
# Resource URL http://ourairports.com/countries/GD/airports.hxl downloaded to ./datasets/List of airports in Grenada (HXL tags).CSV
# Resource URL http://ourairports.com/countries/GW/airports.hxl downloaded to ./datasets/List of airports in Guinea-Bissau (HXL tags).CSV
# Resource URL http://ourairports.com/countries/GM/airports.hxl downloaded to ./datasets/List of airports in Gambia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/GP/airports.hxl downloaded to ./datasets/List of airports in Guadeloupe (HXL tags).CSV
# Resource URL http://ourairports.com/countries/GN/airports.hxl downloaded to ./datasets/List of airports in Guinea (HXL tags).CSV
# Resource URL http://ourairports.com/countries/GI/airports.hxl downloaded to ./datasets/List of airports in Gibraltar (HXL tags).CSV
# Resource URL http://ourairports.com/countries/GH/airports.hxl downloaded to ./datasets/List of airports in Ghana (HXL tags).CSV
# Resource URL http://ourairports.com/countries/FO/airports.hxl downloaded to ./datasets/List of airports in Faeroe Islands (HXL tags).CSV
# Resource URL http://ourairports.com/countries/FK/airports.hxl downloaded to ./datasets/List of airports in Falkland Islands (Malvinas) (HXL tags).CSV
# Resource URL http://ourairports.com/countries/EH/airports.hxl downloaded to ./datasets/List of airports in Western Sahara (HXL tags).CSV
# Resource URL http://ourairports.com/countries/ER/airports.hxl downloaded to ./datasets/List of airports in Eritrea (HXL tags).CSV
# Resource URL http://ourairports.com/countries/DO/airports.hxl downloaded to ./datasets/List of airports in Dominican Republic (HXL tags).CSV
# Resource URL http://ourairports.com/countries/DJ/airports.hxl downloaded to ./datasets/List of airports in Djibouti (HXL tags).CSV
# Resource URL http://ourairports.com/countries/KM/airports.hxl downloaded to ./datasets/List of airports in Comoros (HXL tags).CSV
# Resource URL http://ourairports.com/countries/CK/airports.hxl downloaded to ./datasets/List of airports in Cook Islands (HXL tags).CSV
# Resource URL http://ourairports.com/countries/CM/airports.hxl downloaded to ./datasets/List of airports in Cameroon (HXL tags).CSV
# Resource URL http://ourairports.com/countries/CI/airports.hxl downloaded to ./datasets/List of airports in Côte d'Ivoire (HXL tags).CSV
# Resource URL http://ourairports.com/countries/BT/airports.hxl downloaded to ./datasets/List of airports in Bhutan (HXL tags).CSV
# Resource URL http://ourairports.com/countries/BN/airports.hxl downloaded to ./datasets/List of airports in Brunei Darussalam (HXL tags).CSV
# Resource URL http://ourairports.com/countries/BB/airports.hxl downloaded to ./datasets/List of airports in Barbados (HXL tags).CSV
# Resource URL http://ourairports.com/countries/BM/airports.hxl downloaded to ./datasets/List of airports in Bermuda (HXL tags).CSV
# Resource URL http://ourairports.com/countries/BL/airports.hxl downloaded to ./datasets/List of airports in Saint-Barthélemy (HXL tags).CSV
# Resource URL http://ourairports.com/countries/BH/airports.hxl downloaded to ./datasets/List of airports in Bahrain (HXL tags).CSV
# Resource URL http://ourairports.com/countries/BJ/airports.hxl downloaded to ./datasets/List of airports in Benin (HXL tags).CSV
# Resource URL http://ourairports.com/countries/BI/airports.hxl downloaded to ./datasets/List of airports in Burundi (HXL tags).CSV
# Resource URL http://ourairports.com/countries/AZ/airports.hxl downloaded to ./datasets/List of airports in Azerbaijan (HXL tags).CSV
# Resource URL http://ourairports.com/countries/AS/airports.hxl downloaded to ./datasets/List of airports in American Samoa (HXL tags).CSV
# Resource URL http://ourairports.com/countries/AM/airports.hxl downloaded to ./datasets/List of airports in Armenia (HXL tags).CSV
# Resource URL http://ourairports.com/countries/AI/airports.hxl downloaded to ./datasets/List of airports in Anguilla (HXL tags).CSV
# Resource URL http://ourairports.com/countries/AW/airports.hxl downloaded to ./datasets/List of airports in Aruba (HXL tags).CSV
# Resource URL http://ourairports.com/countries/CD/airports.hxl downloaded to ./datasets/List of airports in Democratic Republic of the Congo (HXL tags).CSV
# Resource URL http://ourairports.com/countries/BO/airports.hxl downloaded to ./datasets/List of airports in Bolivia (Plurinational State of) (HXL tags).CSV
# Resource URL http://ourairports.com/countries/GB/airports.hxl downloaded to ./datasets/List of airports in United Kingdom of Great Britain and Northern Ireland (HXL tags).CSV
# Resource URL http://ourairports.com/countries/LA/airports.hxl downloaded to ./datasets/List of airports in Lao People's Democratic Republic (HXL tags).CSV
# Resource URL https://proxy.hxlstandard.org/data/28342f/download/humanitarian-response-plans.csv downloaded to ./datasets/Humanitarian Response Plans.CSV
# File Removed!
# Resource URL http://ourairports.com/countries/FM/airports.hxl downloaded to ./datasets/List of airports in Micronesia (Federated States of) (HXL tags).CSV
# Resource URL http://ourairports.com/countries/TZ/airports.hxl downloaded to ./datasets/List of airports in United Republic of Tanzania (HXL tags).CSV
# Resource URL http://ourairports.com/countries/IR/airports.hxl downloaded to ./datasets/List of airports in Iran (Islamic Republic of) (HXL tags).CSV
# Resource URL http://ourairports.com/countries/KP/airports.hxl downloaded to ./datasets/List of airports in Democratic People's Republic of Korea (HXL tags).CSV
# Resource URL http://ourairports.com/countries/VC/airports.hxl downloaded to ./datasets/List of airports in Saint Vincent and the Grenadines (HXL tags).CSV
# Resource URL http://ourairports.com/countries/
csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Pakistan downloaded to ./datasets/unhcr-asylum-seekers-determination-pak.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Palau downloaded to ./datasets/unhcr-asylum-seekers-determination-plw.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Panama downloaded to ./datasets/unhcr-asylum-seekers-determination-pan.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Papua%20New%20Guinea downloaded to ./datasets/unhcr-asylum-seekers-determination-png.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Paraguay downloaded to ./datasets/unhcr-asylum-seekers-determination-pry.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Peru downloaded to ./datasets/unhcr-asylum-seekers-determination-per.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Philippines downloaded to ./datasets/unhcr-asylum-seekers-determination-phl.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Poland downloaded to ./datasets/unhcr-asylum-seekers-determination-pol.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Portugal downloaded to ./datasets/unhcr-asylum-seekers-determination-prt.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Qatar downloaded to ./datasets/unhcr-asylum-seekers-determination-qat.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Rep.%20of%20Korea downloaded to ./datasets/unhcr-asylum-seekers-determination-kor.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Rep.%20of%20Moldova downloaded to ./datasets/unhcr-asylum-seekers-determination-mda.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Romania downloaded to ./datasets/unhcr-asylum-seekers-determination-rou.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Russian%20Federation downloaded to ./datasets/unhcr-asylum-seekers-determination-rus.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Rwanda downloaded to ./datasets/unhcr-asylum-seekers-determination-rwa.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Saint%20Kitts%20and%20Nevis downloaded to ./datasets/unhcr-asylum-seekers-determination-kna.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Saint%20Lucia downloaded to ./datasets/unhcr-asylum-seekers-determination-lca.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Saint%20Vincent%20and%20the%20Grenadines downloaded to ./datasets/unhcr-asylum-seekers-determination-vct.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Saudi%20Arabia downloaded to ./datasets/unhcr-asylum-seekers-determination-sau.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Senegal downloaded to ./datasets/unhcr-asylum-seekers-determination-sen.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Serbia%20and%20Kosovo%20%28S/RES/1244%20%281999%29%29 downloaded to ./datasets/unhcr-asylum-seekers-determination-srb.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Sierra%20Leone downloaded to ./datasets/unhcr-asylum-seekers-determination-sle.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Singapore downloaded to ./datasets/unhcr-asylum-seekers-determination-sgp.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Slovakia downloaded to ./datasets/unhcr-asylum-seekers-determination-svk.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Slovenia downloaded to ./datasets/unhcr-asylum-seekers-determination-svn.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Solomon%20Islands downloaded to ./datasets/unhcr-asylum-seekers-determination-slb.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Somalia downloaded to ./datasets/unhcr-asylum-seekers-determination-som.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=South%20Africa downloaded to ./datasets/unhcr-asylum-seekers-determination-zaf.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=South%20Sudan downloaded to ./datasets/unhcr-asylum-seekers-determination-ssd.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Spain downloaded to ./datasets/unhcr-asylum-seekers-determination-esp.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Sri%20Lanka downloaded to ./datasets/unhcr-asylum-seekers-determination-lka.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=State%20of%20Palestine downloaded to ./datasets/unhcr-asylum-seekers-determination-pse.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Sudan downloaded to ./datasets/unhcr-asylum-seekers-determination-sdn.csv.CSV
# File Removed!
# Resource URL http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/asylum_seekers.hxl&filter01=select&select-query01-01=%23country%2Basylum=Suriname downloaded to ./datasets/unhcr-asylum-seekers-determination-sur.csv.CSV
# File Removed!

# %%
for i in range(1000, 1500):
    process_dataset(datasets_HXL[i], 'CSV', headers_and_tags, './datasets', count)

# %%
headers_and_tags.to_excel("headandtags.xlsx")
